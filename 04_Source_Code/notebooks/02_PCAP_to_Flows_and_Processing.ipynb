# %%
# PCAP to Flows and Processing

from pathlib import Path
from services.data_ingestion.pcap_loader import pcap_to_flows_with_cicflowmeter

pcap_path = ''  # set your pcap path
output_csv = str(Path('../../01_Data/02_Processed/flows_from_pcap.csv').resolve())

if pcap_path:
    df = pcap_to_flows_with_cicflowmeter(pcap_path, output_csv=output_csv)
    display(df.head())
    print('Saved:', output_csv)
