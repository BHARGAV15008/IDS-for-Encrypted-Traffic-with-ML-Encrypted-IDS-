# %%
# CSV Ingestion and Cleaning

import pandas as pd
from pathlib import Path

from services.data_ingestion.csv_loader import load_csv_dataset

sample_path = str(Path('../../01_Data/02_Processed').resolve())
print('Set your CSV path in variable csv_path')
csv_path = ''

if csv_path:
    df = load_csv_dataset(csv_path)
    display(df.head())
    print(df.describe(include='all').transpose().head(20))
