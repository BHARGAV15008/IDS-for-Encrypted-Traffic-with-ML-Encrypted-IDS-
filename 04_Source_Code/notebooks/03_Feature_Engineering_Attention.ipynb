# %%
# Feature Engineering with Attention

import torch
import pandas as pd

from services.model_service.hybrid_attention_model import HybridCNNBiLSTMAttention

# demo shapes: batch=4, seq=100, feat=32
x = torch.randn(4, 100, 32)
model = HybridCNNBiLSTMAttention(input_features=32, num_classes=5)
logits = model(x)
logits.shape
