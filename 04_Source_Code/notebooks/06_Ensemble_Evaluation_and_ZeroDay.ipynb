# %%
# Ensemble Evaluation and Zero-Day

import numpy as np
from services.ensemble_service.ensemble_classifier import EnsembleClassifier

X = np.random.randn(100, 128)
y = np.random.randint(0, 5, size=100)

ensemble = EnsembleClassifier(base_dim=128, num_classes=5)
ensemble.fit(X, y)
preds = ensemble.predict(X[:10])
preds
