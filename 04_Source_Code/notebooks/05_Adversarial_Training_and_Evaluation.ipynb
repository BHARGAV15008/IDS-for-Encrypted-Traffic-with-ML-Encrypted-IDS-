# %%
# Adversarial Training and Evaluation

import torch
import torch.nn as nn
import torch.optim as optim

from services.model_service.hybrid_attention_model import HybridCNNBiLSTMAttention
from services.adversarial_service.trainer import adversarial_training_step

model = HybridCNNBiLSTMAttention(input_features=32, num_classes=5)
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

x = torch.randn(16, 100, 32)
y = torch.randint(0, 5, (16,))

loss = adversarial_training_step(model, loss_fn, optimizer, x, y, epsilon=0.01)
loss
